# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52066/2303A52066_stml/blob/main/STML_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
data=pd.read_csv('/content/diabetes_data_upload 3.csv')
data.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...

# %%
target_var = data['class']
target_var.head()
# Out:
# 0    Positive
# 1    Positive
# 2    Positive
# 3    Positive
# 4    Positive
# Name: class, dtype: object

# %%
b=data.drop('class',axis=1)
b.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity
# 0              No              Yes      Yes     Yes
# ...

# %%
replace=data.replace({"positive:1","negative:0"})
replace.head()
# Out:
# <ipython-input-7-fc4974c1bb81>:1: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   replace=data.replace({"positive:1","negative:0"})
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# ...

# %%
replace1=data.replace({"Male":11,"Female":00})
replace1.head()
# Out:
#    Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40      11       No        Yes                 No      Yes         No
# 1   58      11       No         No                 No      Yes         No
# 2   41      11      Yes         No                 No      Yes        Yes
# 3   45      11       No         No                Yes      Yes        Yes
# 4   60      11      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...

# %%
replace2=data.replace({"No":11,"Yes":00})
replace2.head()
# Out:
#    Age Gender  Polyuria  Polydipsia  sudden weight loss  weakness  Polyphagia  \
# 0   40   Male        11           0                  11         0          11
# 1   58   Male        11          11                  11         0          11
# 2   41   Male         0          11                  11         0           0
# 3   45   Male        11          11                   0         0           0
# 4   60   Male         0           0                   0         0           0
#
#    Genital thrush  visual blurring  Itching  Irritability  delayed healing  \
# 0              11               11        0            11                0
# 1              11                0       11            11               11
# 2              11               11        0            11                0
# 3               0               11        0            11                0
# 4              11                0        0             0                0
#
# ...

# %%
from sk learn.model_selection
